# %%
import mwclient  # библиотека для работы с MediaWiki API для загрузки примеров статей Википедии
import mwparserfromhell  # Парсер для MediaWiki
import openai  # будем использовать для токинизации
import pandas as pd  # В DataFrame будем хранить базу знаний и результат токинизации базы знаний
import re  # для вырезания ссылок <ref> из статей Википедии
import tiktoken  # для подсчета токенов
from typing import List, Set, Tuple

# %%
# Соберем заголовки всех статей
def titles_from_category(
    category: mwclient.listing.Category, # Задаем типизированный параметр категории статей
    max_depth: int # Определяем глубину вложения статей
) -> Set[str]:
    """Возвращает набор заголовков страниц в данной категории Википедии и ее подкатегориях."""
    titles = set() # Используем множество для хранения заголовков статей
    for cm in category.members(): # Перебираем вложенные объекты категории
        if type(cm) == mwclient.page.Page: # Если объект является страницей
            titles.add(cm.name) # в хранилище заголовков добавляем имя страницы
        elif isinstance(cm, mwclient.listing.Category) and max_depth > 0: # Если объект является категорией и глубина вложения не достигла максимальной
            deeper_titles = titles_from_category(cm, max_depth=max_depth - 1) # вызываем рекурсивно функцию для подкатегории
            titles.update(deeper_titles) # добавление в множество элементов из другого множества
    return titles

# %%
CATEGORY_TITLE = "Category:Automotive industry"
WIKI_SITE = "en.wikipedia.org"

# Инициализация объекта MediaWiki
# WIKI_SITE ссылается на англоязычную часть Википедии
site = mwclient.Site(WIKI_SITE)

# Загрузка раздела заданной категории
category_page = site.pages[CATEGORY_TITLE]

# %%
# Получение множества всех заголовков категории с вложенностью на один уровень
titles = titles_from_category(category_page, max_depth=1)


print(f"Создано {len(titles)} заголовков статей в категории {CATEGORY_TITLE}.")
# Out:
# Создано 803 заголовков статей в категории Category:Automotive industry.

# %%
SECTIONS_TO_IGNORE = [
    "See also",
    "References",
    "External links",
    "Further reading",
    "Footnotes",
    "Bibliography",
    "Sources",
    "Citations",
    "Literature",
    "Footnotes",
    "Notes and references",
    "Photo gallery",
    "Works cited",
    "Photos",
    "Gallery",
    "Notes",
    "References and sources",
    "References and notes",
]

# %%
# Функция возвращает список всех вложенных секций для заданной секции страницы Википедии

def all_subsections_from_section(
    section: mwparserfromhell.wikicode.Wikicode, # текущая секция
    parent_titles: List[str], # Заголовки родителя
    sections_to_ignore: Set[str], # Секции, которые необходимо проигнорировать
) -> List[Tuple[List[str], str]]:
    """
    Из раздела Википедии возвращает список всех вложенных секций.
    Каждый подраздел представляет собой кортеж, где:
      - первый элемент представляет собой список родительских секций, начиная с заголовка страницы
      - второй элемент представляет собой текст секции
    """

    # Извлекаем заголовки текущей секции
    headings = [str(h) for h in section.filter_headings()]
    title = headings[0]
    # Заголовки Википедии имеют вид: "== Heading =="

    if title.strip("=" + " ") in sections_to_ignore:
        # Если заголовок секции в списке для игнора, то пропускаем его
        return []

    # Объединим заголовки и подзаголовки, чтобы сохранить контекст для chatGPT
    titles = parent_titles + [title]

    # Преобразуем wikicode секции в строку
    full_text = str(section)

    # Выделяем текст секции без заголовка
    section_text = full_text.split(title)[1]
    if len(headings) == 1:
        # Если один заголовок, то формируем результирующий список
        return [(titles, section_text)]
    else:
        first_subtitle = headings[1]
        section_text = section_text.split(first_subtitle)[0]
        # Формируем результирующий список из текста до первого подзаголовка
        results = [(titles, section_text)]
        for subsection in section.get_sections(levels=[len(titles) + 1]):
            results.extend(
                # Вызываем функцию получения вложенных секций для заданной секции
                all_subsections_from_section(subsection, titles, sections_to_ignore)
                )  # Объединяем результирующие списки данной функции и вызываемой
        return results

# %%
def all_subsections_from_title(
    title: str, # Заголовок статьи Википедии, которую парсим
    sections_to_ignore: Set[str] = SECTIONS_TO_IGNORE, # Секции, которые игнорируем
    site_name: str = WIKI_SITE, # Ссылка на сайт википедии
) -> List[Tuple[List[str], str]]:
    """
    Из заголовка страницы Википедии возвращает список всех вложенных секций.
    Каждый подраздел представляет собой кортеж, где:
      - первый элемент представляет собой список родительских секций, начиная с заголовка страницы
      - второй элемент представляет собой текст секции
    """

    # Инициализация объекта MediaWiki
    # WIKI_SITE ссылается на англоязычную часть Википедии
    site = mwclient.Site(site_name)

    # Запрашиваем страницу по заголовку
    page = site.pages[title]

    # Получаем текстовое представление страницы
    text = page.text()

    # Удобный парсер для MediaWiki
    parsed_text = mwparserfromhell.parse(text)
    # Извлекаем заголовки
    headings = [str(h) for h in parsed_text.filter_headings()]
    if headings: # Если заголовки найдены
        # В качестве резюме берем текст до первого заголовка
        summary_text = str(parsed_text).split(headings[0])[0]
    else:
        # Если нет заголовков, то весь текст считаем резюме
        summary_text = str(parsed_text)
    results = [([title], summary_text)] # Добавляем резюме в результирующий список
    for subsection in parsed_text.get_sections(levels=[2]): # Извлекаем секции 2-го уровня
        results.extend(
            # Вызываем функцию получения вложенных секций для заданной секции
            all_subsections_from_section(subsection, [title], sections_to_ignore)
        ) # Объединяем результирующие списки данной функции и вызываемой
    return results

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 titles[0]
#
# TypeError: 'set' object is not subscriptable

# %%
# Разбивка статей на секции
# придется немного подождать, так как на парсинг 100 статей требуется около минуты
wikipedia_sections = []
for idx, title in enumerate(titles):
    print(idx, title)
    wikipedia_sections.extend(all_subsections_from_title(title))
print(f"Найдено {len(wikipedia_sections)} секций на {len(titles)} страницах")
# Out:
# 0 NZ Performance Car
# 1 SsangYong WZ
# 2 Pac-car II
# 3 Head-up display
# 4 Rebadging
# 5 Vehicle frame
# 6 Technischer Überwachungsverein
# 7 DNV Fuel Fighter
# 8 1950s American automobile culture
# 9 EUKOR
# 10 Riversimple Urban Car
# 11 Grimaldi Group
# 12 Quill drive
# 13 UW Hybrid Vehicle Team
# 14 AMC Rambler Tarpon
# 15 Fleet special
# 16 Yamaha OX99-11
# 17 Japanese Automotive Standards Organization
# 18 Automotive aftermarket
# 19 ULTRA AP
# 20 Mallika Srinivasan
# 21 Underseal
# 22 Body solder
# 23 List of countries by motor vehicle production in the 2010s
# 24 Experimental safety vehicle
# 25 Ford Mighty F-350
# 26 Steam Automobile Club of America
# 27 QS9000
# 28 Novo (car)
# 29 Dogo SS-2000
# 30 Capitalism: A Love Story
# 31 General Motors of Canada Ltd v City National Leasing
# 32 Electronic parking brake
# 33 Millbrook Proving Ground
# 34 Retail floorplan
# 35 Benjamin Briscoe
# 36 Robotaxi
# 37 Rolling code
# 38 United European Car Carriers
# 39 Glossary of automotive design
# 40 Hyundai Glovis
# 41 Automobile magazine
# 42 MERCON
# 43 Paxton Phoenix
# 44 Delay box
# 45 Mr. Horsepower
# 46 Automotive industry in Turkey
# 47 L'Auto-Journal
# 48 Mercury Meta One
# 49 Range Stormer
# 50 Duco
# 51 EDAG Cinema 7D
# 52 Al Habtoor Motors LLC
# 53 Marshall Teague (racing driver)
# 54 Merrill Wheel-Balancing System
# 55 Valencia Assembly
# 56 Driven To Perform
# 57 Wayne Carini
# 58 Automotive News
# 59 International Material Data System
# 60 2004 in motoring
# 61 Catalytic converter
# 62 Ghia Selene
# 63 Salvage Squad
# 64 Frederick C. Crawford
# 65 Kurt Lotz
# 66 Virgil Exner
# 67 Transparent Prototype
# 68 Automotive industry in Romania
# 69 Hand-built by robots
# 70 Jon Reep
# 71 Car dealership
# 72 Longitudinal engine
# 73 Samelet
# 74 Peter Schreyer
# 75 Owen Nacker
# 76 Tourmobile
# 77 1990 in motoring
# 78 Doug Roby
# 79 H-point
# 80 Autobesity
# 81 Variable reluctance sensor
# 82 AC Propulsion eBox
# 83 Hopium
# 84 1996 in motoring
# 85 1981 in motoring
# 86 Suzuki GSX-R/4
# 87 1998 in motoring
# 88 Fast fuel system
# 89 Ksau's Motors
# 90 Phantom Corsair
# 91 1984 in motoring
# 92 Lotus M90
# 93 Paul G. Hahnemann
# 94 Federal Motor Vehicle Safety Standard 208
# 95 Tilden Rent-A-Car Co v Clendenning
# 96 Laurence Hartnett
# 97 List of countries by automotive component exports
# 98 Ralph Peo
# 99 PAS 777
# 100 Proton Lekir
# 101 James Fuller (automobile executive)
# 102 Michael Macht
# 103 Bavarian Auto Group
# 104 Mini Beachcomber
# 105 Spoiler (car)
# 106 Emergency vehicle lighting
# 107 Apollo Arrow
# 108 Vehicle-to-vehicle (energy storage)
# 109 Sodablasting
# 110 Peak (automotive products)
# 111 Federal Motor Vehicle Safety Standard 226
# 112 Smart Crosstown
# 113 OBD-II PIDs
# 114 Enovate ME-Sports
# 115 William C. Durant
# 116 Facelift (automotive)
# 117 Pre-production car
# 118 Federal Motor Vehicle Safety Standard 126
# 119 Tachograph
# 120 George E. Daniels
# 121 Alvan Macauley
# 122 CJ Fraleigh
# 123 Liquid nitrogen engine
# 124 Georges Martin (engineer)
# 125 Jay Ohrberg
# 126 Dymaxion car
# 127 LAX Consolidated Rent-A-Car Facility
# 128 Who Killed Vincent Chin?
# 129 Revenge of the Electric Car
# 130 Toni Schmücker
# 131 Stena Line
# 132 Classic Car Club of America
# 133 David Grainger (presenter)
# 134 Taken for a Ride
# 135 Eadon Green Black Cuillin
# 136 Andrew J. Crevolin
# 137 Women in the automotive industry
# 138 History of the automobile
# 139 Launch control (automotive)
# 140 K Line
# 141 Dynamo 9.0
# 142 ChaoJi
# 143 Malaise era
# 144 Automotive industry in Croatia
# 145 High-definition map
# 146 Stout Scarab
# 147 Tire mousse
# 148 Michael Manley (CEO)
# 149 List of countries by motor vehicle production
# 150 Castagna Imperial Landaulet
# 151 Classic car
# 152 2003 in motoring
# 153 Eliica
# 154 Car coat
# 155 Yanase (car dealership)
# 156 1992 in motoring
# 157 Cutting compound
# 158 Car Warriors (TV series)
# 159 Antifreeze
# 160 End of Life Vehicles Directive
# 161 Bugatti Type 252
# 162 Car relocation
# 163 Articulated vehicle
# 164 1997 in motoring
# 165 Car rental
# 166 Final Offer
# 167 Robert Cumberford
# 168 Atlantic Container Line
# 169 1983 in motoring
# 170 GAC Enverge
# 171 Sisteplant
# 172 1993 in motoring
# 173 Federal Motor Vehicle Safety Standard 106
# 174 Edward B. Montgomery
# 175 Bajaj Lite
# 176 Parts book
# 177 Jean Jennings
# 178 MOST Bus
# 179 Minor automotive manufacturing groups
# 180 Apex AP-0
# 181 List of manufacturers by motor vehicle production
# 182 Automotive Industry Standard 140
# 183 Teknikens Värld
# 184 Car elevator
# 185 Ulrich Eichhorn
# 186 The Car Show
# 187 Pan Ocean
# 188 Pasha Hawaii
# 189 Maximiliano Larroquette
# 190 Rolls-Royce 100EX
# 191 Alec Issigonis
# 192 Automotive industry in Belarus
# 193 Diffuser (automotive)
# 194 Automobile salesperson
# 195 Iveco Vision
# 196 Autorack
# 197 Semi-trailer aerodynamic device
# 198 Automotive industry in the United States
# 199 Jill Lajdziak
# 200 Wiel Motor Magazine
# 201 Mazel Group Engineering
# 202 AURES Holdings
# 203 1978 in motoring
# 204 SKAF (automobile)
# 205 Edsel Ford II
# 206 K Line European Sea Highway Services
# 207 Mazel Identity i1
# 208 Consolidated rental car facility
# 209 Sid Ramnarace
# 210 Fiat ESVs
# 211 2008–2010 automotive industry crisis
# 212 Russo-Balt
# 213 Tire-pressure monitoring system
# 214 1,1,1,2-Tetrafluoroethane
# 215 George W. Drum
# 216 Wallenius Wilhelmsen Logistics
# 217 Toyofuji Shipping
# 218 Eugene Bordinat
# 219 Dynamic steering response
# 220 Power antenna
# 221 Iso Varedo
# 222 Semon Knudsen
# 223 Subcompact crossover SUV
# 224 NamX HUV
# 225 Sport auto (France)
# 226 Ponton (car)
# 227 Soundaktor
# 228 Vehicle dynamics
# 229 Spot delivery
# 230 Rudolf Leiding
# 231 Frem F1
# 232 Vehicle-to-load
# 233 Rinspeed Presto
# 234 European Automotive Design
# 235 Ledyard Mitchell
# 236 Emission test cycle
# 237 Speeding. No one thinks big of you.
# 238 Mercury My
# 239 Roel de Vries (engineer)
# 240 Chevron Cars
# 241 Ford Model A engine
# 242 EcoJet concept car
# 243 Coso artifact
# 244 Personal Car Communicator
# 245 Captive import
# 246 SAE J2452
# 247 Transponder car key
# 248 T.25
# 249 Hydraulic hybrid vehicle
# 250 Triumph Fury
# 251 Parts bin special
# 252 Program on Vehicle and Mobility Innovation
# 253 Isotta Fraschini T8 and T12
# 254 MG EX-E
# 255 Tommykaira ZZII
# 256 Samir Sadikhov
# 257 Docker Daimlers
# 258 Body-in-Blue
# 259 Ageing suit
# 260 Time Magazine Quality Dealer Award
# 261 Sergio Marchionne
# 262 SAE J1939
# 263 Manufacturer's Certificate of Origin
# 264 Cerence
# 265 Triple-hybrid
# 266 The Last Truck: Closing of a GM Plant
# 267 Auto (company)
# 268 Mercedes-Benz Vision EQ Silver Arrow
# 269 Fritz Nallinger
# 270 Bondo (putty)
# 271 Electric car
# 272 Rinspeed Yello Talbo
# 273 Development mule
# 274 Automotive warranty
# 275 Vorsprung durch Technik
# 276 Joska Bourgeois
# 277 Amadeo Barletta Barletta
# 278 SENT (protocol)
# 279 Association for Standardisation of Automation and Measuring Systems
# 280 Mercury XM-800
# 281 LHM (hydraulic fluid)
# 282 James H. Whiting
# 283 Federal Motor Vehicle Safety Standard 116
# 284 Vacuum delay valve
# 285 Automotive technology
# 286 Émile Mathis
# 287 Pep Boys
# 288 Bi-fuel vehicle
# 289 State of health
# 290 Jacques Nasser
# 291 James McLernon
# 292 Automotive security
# 293 Automotive Industry Action Group
# 294 Packard Panther
# 295 Automotive industry in Serbia
# 296 Employee pricing
# 297 Michelin Man
# 298 Abarth 1500 Biposto
# 299 Motor oil
# 300 Heuliez Raffica
# 301 Wallenius Wilhelmsen
# 302 Scrappage program
# 303 Knock-down kit
# 304 Who Killed the Electric Car?
# 305 DEXRON
# 306 SAE J1587
# 307 Scottish Aviation Scamp
# 308 Vehicle identification number
# 309 Beechcraft Plainsman
# 310 1987 in motoring
# 311 L. David Ash
# 312 Drivetrain
# 313 Automotive industry in Egypt
# 314 Conservation and restoration of road vehicles
# 315 World Forum for Harmonization of Vehicle Regulations
# 316 Pininfarina Sintesi
# 317 1986 in motoring
# 318 Design studio
# 319 Land Rover DC100
# 320 Horseless carriage
# 321 Mini concept cars
# 322 UMW Toyota Motor
# 323 1985 in motoring
# 324 2,3,3,3-Tetrafluoropropene
# 325 Kjell Qvale
# 326 Direct TPMS
# 327 CSAV
# 328 Motor Trader Magazine
# 329 Car dependency
# 330 Omega (car)
# 331 Heater core
# 332 The Car Chasers
# 333 Schlörwagen
# 334 Automotive industry in Indonesia
# 335 Roger & Me
# 336 Fesco Transport Group
# 337 Mini Aceman
# 338 List of years in motoring
# 339 Alpine Alpenglow
# 340 Anand Mahindra
# 341 Muscats Motors
# 342 Eric Stoddard
# 343 Rolf (company)
# 344 Henry J. Kaiser
# 345 1994 in motoring
# 346 Siem Shipping
# 347 Autofil
# 348 Minicar RSV
# 349 History of the diesel car
# 350 Waterman Steamship Corporation
# 351 Karl Wilfert
# 352 Put a tiger in your tank
# 353 Dedicated short-range communications
# 354 Bahri (company)
# 355 Wilh. Wilhelmsen
# 356 Auto auction
# 357 Pininfarina H2 Speed
# 358 The Home-Made Car
# 359 Compact crossover SUV
# 360 Stanley Gillen
# 361 DTU Roadrunners
# 362 Vision Gran Turismo
# 363 Taximeter
# 364 Lakshmi Venu
# 365 Modular vehicle
# 366 Nobe GT100
# 367 Sunny Car Center
# 368 NFPA 1901
# 369 Automotive Network Exchange
# 370 1979 in motoring
# 371 Philip T. Clark
# 372 List of most expensive cars sold at auction
# 373 Propane, butane, and LPG container valve connections
# 374 Safe Road Trains for the Environment
# 375 Remote keyless system
# 376 Talk:1985 in motoring
# 377 Vector WX-8
# 378 NZV8 (magazine)
# 379 Electromod
# 380 Aiways U6 ion
# 381 Auto row
# 382 Rain-X
# 383 Eidsiva Rederi
# 384 Car phone
# 385 North American Charging Standard
# 386 When Rover Met BMW
# 387 Car platform
# 388 Automotive industry in Ukraine
# 389 Smart Forstars
# 390 Trim level (automobile)
# 391 Classic Car Rescue
# 392 ALDL
# 393 British Leyland ECV3
# 394 Transportation Research Center
# 395 Berjaya Auto Alliance
# 396 McLaren MP4-X
# 397 Platoon (automobile)
# 398 Tom Gale (designer)
# 399 Open Automotive Alliance
# 400 Wheel sizing
# 401 L'Œuf électrique
# 402 Automotive Research & Testing Center
# 403 Mercury Messenger (concept car)
# 404 Lotec C1000
# 405 Fernand Picard (engineer)
# 406 Terence Beckett
# 407 List of car magazines
# 408 2001 in motoring
# 409 Theon Design
# 410 History of self-driving cars
# 411 Pierce Silver Arrow
# 412 Hyundai AutoEver
# 413 Solar bus
# 414 Vehicle audio
# 415 Red Bull X2010
# 416 Max Hoffman
# 417 Motormag
# 418 Harold Sines Vance
# 419 CityCar
# 420 Donald N. Frey
# 421 Advanced Train Control System
# 422 Window deflector
# 423 IATF 16949
# 424 Neorion Chicago
# 425 Raymond Loewy
# 426 William Clay Ford Jr.
# 427 GB/T charging standard
# 428 Dick Teague
# 429 Acura CL-X
# 430 1999 in motoring
# 431 Panhard Dynavia
# 432 Clement Studebaker Jr.
# 433 Scion Fuse
# 434 Mobile metering
# 435 David E. Davis
# 436 Automotive lighting
# 437 Wallenius Lines
# 438 SAE J300
# 439 DOT 5.1
# 440 Fuzz Townshend
# 441 DOT 4
# 442 Automotive industry
# 443 The Dog & Lemon Guide
# 444 Hongqi S9
# 445 Automotive design
# 446 Pininfarina Nido
# 447 SRT Tomahawk
# 448 E-four
# 449 Howard "Dutch" Darrin
# 450 AK Syrena Meluzyna
# 451 Minissima
# 452 Frank Hershey
# 453 Smart For-Us
# 454 Sime Darby
# 455 Hanns Grewenig
# 456 Detropia
# 457 Aiways U7 ion
# 458 Rinspeed Mono Ego
# 459 Braking test track
# 460 Collector Car Appreciation Day
# 461 Heinz Prechter
# 462 William Clay Ford Sr.
# 463 Classic Motorsports
# 464 Barn find
# 465 4 Ruedas Magazine
# 466 World Motorcycle Test Cycle
# 467 Litocar
# 468 Josiah Dallas Dort
# 469 Production vehicle
# 470 Fahrvergnügen
# 471 Rover CCV
# 472 Vosco S106
# 473 Megawatt Charging System
# 474 Mizzou Hydrogen Car Team
# 475 SAE J2807
# 476 Alan Lubinsky
# 477 Aurora (1957 automobile)
# 478 Panoz Abruzzi
# 479 Smart Formore
# 480 Jim Dunne
# 481 SAE International
# 482 Avtomanija
# 483 Brass Era car
# 484 Edaran Otomobil Nasional
# 485 Keyword Protocol 2000
# 486 On-board diagnostics
# 487 Eagle Optima
# 488 2002 in motoring
# 489 Airless tire
# 490 Automatic transmission fluid
# 491 Ganja Auto Plant
# 492 Windshield washer fluid
# 493 Type 2 connector
# 494 AMC Cavalier
# 495 Errett Lobban Cord
# 496 Genesis New York
# 497 Astra International
# 498 List of countries by engine exports
# 499 Eco-Runner Team Delft
# 500 Fleet vehicle
# 501 Federal Motor Vehicle Safety Standard 401
# 502 Lotus Ethos
# 503 List of auto dealership and repair shop buildings
# 504 Melkus PT 73 Spyder
# 505 Al Volante
# 506 Tan Chong Motor
# 507 Hydrogen vehicle
# 508 Automotive industry in Uzbekistan
# 509 Rover T3
# 510 Hardtop
# 511 Decrepit car
# 512 VisLab
# 513 Big Three (automobile manufacturers)
# 514 Brake fluid
# 515 Nissan Motor Car Carrier
# 516 Weymann Fabric Bodies
# 517 Soletta 750
# 518 Horatio's Drive: America's First Road Trip
# 519 Lancia Stratos Zero
# 520 Ikenga GT
# 521 Willem Weertman
# 522 Alexander Trotman, Baron Trotman
# 523 GB/T 20234.2-2015
# 524 DRB-HICOM
# 525 Automóvil
# 526 Buy here, pay here
# 527 Federal Motor Vehicle Safety Standard 108
# 528 Turtle Wax
# 529 Mitsui O.S.K. Lines
# 530 Tesla Supercharger
# 531 Koenigsegg CC
# 532 Rust Heinz
# 533 Vector WX-3
# 534 The Very Light Car
# 535 2 Cheap Cars
# 536 Finch Restorations
# 537 Automobile products liability
# 538 Antique car
# 539 Dome Zero
# 540 American automobile industry in the 1950s
# 541 Sherwood Egbert
# 542 VisLab Intercontinental Autonomous Challenge
# 543 SAE J2450
# 544 World car
# 545 Car finance
# 546 Car model
# 547 Automotive industry in Hungary
# 548 NATRAX
# 549 Stone damage
# 550 Fisker Atlantic
# 551 Duncan Aldred
# 552 Messina Line
# 553 Richard E. Cross
# 554 Houdina Radio Control
# 555 Self-driving car
# 556 Fisker Surf
# 557 Heinrich Nordhoff
# 558 Transverse engine
# 559 Plug-in hybrid
# 560 Speed shop
# 561 Auto Atlantic
# 562 Car SOS
# 563 Carl Hahn
# 564 Aspöck Systems
# 565 Exhaust heat recovery system
# 566 Sony Vision-S
# 567 Joseph Lowthian Hudson
# 568 Alcantara (material)
# 569 Leif Höegh & Co
# 570 Automotive paint
# 571 Automotive industry in Argentina
# 572 Vintage car
# 573 CarPrice
# 574 Rolls-Royce 102EX
# 575 Shift kit
# 576 List of countries by motor vehicle production in the 2000s
# 577 William S. Knudsen
# 578 Thomas Pullinger
# 579 Saleen S5S Raptor
# 580 Cruise control
# 581 Scion Hako Coupe
# 582 RM Sotheby's
# 583 Gerd Stieler von Heydekampf
# 584 Powertrain
# 585 1982 in motoring
# 586 Rinspeed sQuba
# 587 Automotive industry in the Soviet Union
# 588 Sbarro (automobile)
# 589 Cold shrinking
# 590 Lotus APX
# 591 Floating Power
# 592 Hotai Motor
# 593 Euro Marine Logistics
# 594 SAE J3068
# 595 Model year
# 596 Simoniz
# 597 For the Love of Cars
# 598 List of countries by truck exports
# 599 Cars in the 1920s
# 600 Albert A. Ultcht
# 601 Automotive head-up display
# 602 Ultrasuede
# 603 Angkor EV
# 604 Automotive industry in Slovakia
# 605 Driving cycle
# 606 Monteverdi Palm Beach
# 607 Klaus von Oertzen
# 608 Tesla Autopilot
# 609 Canada–United States Automotive Products Agreement
# 610 SAE J3105
# 611 VTNZ
# 612 Automotive industry in Bulgaria
# 613 VDub
# 614 Denzel (automobile)
# 615 Sir Vival
# 616 Windsor T. White
# 617 John E. Herlitz
# 618 Vector Informatik
# 619 Wrightspeed X1
# 620 Production part approval process
# 621 Smart Forspeed
# 622 Vi Bilägare
# 623 Concours d'Elegance
# 624 Unified Diagnostic Services
# 625 Vehicle infrastructure integration
# 626 Prodrive P2
# 627 Federal Motor Vehicle Safety Standard 138
# 628 Ken Garff
# 629 Code of Openness
# 630 Ayax
# 631 ISO 26262
# 632 Motorships
# 633 Richard Arbib
# 634 Cyklonetka
# 635 Jimenez Novia
# 636 Automotive Technician Accreditation
# 637 Shipping agency
# 638 Time-triggered architecture
# 639 DAF Siluro
# 640 Car controls
# 641 J1922
# 642 Ballast (car racing)
# 643 Tachometer
# 644 1995 in motoring
# 645 SAE J1708
# 646 Weather Eye
# 647 Assured clear distance ahead
# 648 Grey import vehicle
# 649 Virtual tuning
# 650 Großer Stoewer Motorwagen
# 651 SAE J306
# 652 Historic Vehicle Association
# 653 DIN 72552
# 654 Papa and Nicole
# 655 Mr. Opportunity
# 656 Compressed-air car
# 657 Bendix SWC
# 658 Range Rover Evoque
# 659 ISIRI 13139
# 660 Start-stop system
# 661 FSO Syrena Sport
# 662 Microdot (car)
# 663 Nippon Yusen
# 664 FSO Ogar
# 665 AMC AMX-GT
# 666 List of international auto shipping companies
# 667 Golden Sahara II
# 668 Power Magazine
# 669 Pilgrim of Providence
# 670 Peugeot Concours Design
# 671 Advanced product quality planning
# 672 T. V. Sundram Iyengar
# 673 Challenge X
# 674 Self-driving truck
# 675 Omniview technology
# 676 Argo AI
# 677 Packard Pan-American
# 678 FSO Warszawa
# 679 Automóvil Panamericano
# 680 Fédération Internationale des Véhicules Anciens
# 681 2000 in motoring
# 682 1989 in motoring
# 683 When Heaven Was at the Corner of Sycamore and Main
# 684 Roof module
# 685 Timeline of European automobiles
# 686 Budd XR-400
# 687 SAE J3400
# 688 Car longevity
# 689 Alliance of Automobile Manufacturers
# 690 Soybean car
# 691 Dynamometer
# 692 Oil catch tank
# 693 Roof flap
# 694 Joe Isuzu
# 695 1980 in motoring
# 696 Conservation and restoration of rail vehicles
# 697 Abdul Latif Jameel
# 698 1988 in motoring
# 699 Jack Irving
# 700 Rick Wagoner
# 701 NZ Classic Car magazine
# 702 Vehicle-to-home
# 703 Handsfree
# 704 DOT 5
# 705 Morpheus (The Matrix)
# 706 Horatio Nelson Jackson
# 707 Retractable hardtop
# 708 Car colour popularity
# 709 Toyota Kenya
# 710 CHAdeMO
# 711 Autoglym
# 712 EcoCAR
# 713 European delivery
# 714 Alex Tremulis
# 715 Astra-Gnome
# 716 Brooks Stevens
# 717 Timeline of motor vehicle brands
# 718 2009–2011 Toyota vehicle recalls
# 719 Car Mechanics
# 720 Combined Charging System
# 721 Electrosport
# 722 Voyah i-Land
# 723 Charge-depleting
# 724 Gear oil
# 725 Have You Driven a Ford Lately
# 726 Car carrier trailer
# 727 SEMA
# 728 Suzuki G70
# 729 Chasing Classic Cars
# 730 Colonial Motor Company
# 731 Vehicle-to-grid
# 732 Auto transport broker
# 733 LHS (hydraulic fluid)
# 734 Automotive industry in Russia
# 735 Wheels Magazine (Sweden)
# 736 Barney Roos
# 737 Dashcam
# 738 Glass's Guide
# 739 Philippe Klein
# 740 Quattroruote
# 741 Concept car
# 742 Gleagle GS-CC
# 743 Helicron (automobile)
# 744 Leonard Crossland
# 745 Vector W2
# 746 Paint protection film
# 747 Automotive industry by country
# 748 Battery electric vehicle
# 749 Vehicle regulation
# 750 Isdera Commendatore 112i
# 751 Lightweighting
# 752 1991 in motoring
# 753 James J. Nance
# 754 ASL Garaiya
# 755 Association of Car Rental Industry Systems Standards
# 756 SAE J1772
# 757 Automotive Electronics Council
# 758 Back-up beeper
# 759 AMAG Automobil- und Motoren
# 760 Chassis dynamometer
# 761 Motor Manual
# 762 Ultima Mk1
# 763 Japan Automotive Hall of Fame
# 764 Abarth T140
# 765 Hyosung
# 766 AC Propulsion tzero
# 767 Spaceframe chassis
# 768 Daewoo Motor Sales
# 769 International Centre for Automotive Technology
# 770 ISO 7637
# 771 Felix the Cat
# 772 Richard M. Langworth
# 773 Dynamo 7.0
# 774 Type 3 connector
# 775 David Plastow
# 776 Proton Kasturi
# 777 Spyker Silvestris V8
# 778 Timeline of North American automobiles
# 779 Custom car
# 780 DeepRoute.ai
# 781 Charles E. Spahr
# 782 Ryan Nagode
# 783 Damage waiver
# 784 Steam car
# 785 Cruisin' Style Magazine
# 786 Ram-air intake
# 787 Wheeler Dealers
# 788 Hemmings Motor News
# 789 DOT 3
# 790 American Roll-on Roll-off Carrier
# 791 Isuzu 4200R
# 792 Counting Cars
# 793 Automobile Dealer Economic Rights Restoration Act
# 794 Kinetic energy recovery system
# 795 Polestar Precept
# 796 Italdesign Machimoto
# 797 Stressed skin
# 798 Quatro Rodas
# 799 Rick Dore
# 800 California Mille
# 801 Crossover (automobile)
# 802 Anti-electric vehicle tactics in the US and Canada
# Найдено 5466 секций на 803 страницах

# %%
# Очистка текста секции от ссылок <ref>xyz</ref>, начальных и конечных пробелов
def clean_section(section: Tuple[List[str], str]) -> Tuple[List[str], str]:
    titles, text = section
    # Удаляем ссылки
    text = re.sub(r"<ref.*?</ref>", "", text)
    # Удаляем пробелы вначале и конце
    text = text.strip()
    return (titles, text)

# %%
# Применим функцию очистки ко всем секциям с помощью генератора списков
wikipedia_sections = [clean_section(ws) for ws in wikipedia_sections]

# %%
# Отфильтруем короткие и пустые секции
def keep_section(section: Tuple[List[str], str]) -> bool:
    """Возвращает значение True, если раздел должен быть сохранен, в противном случае значение False."""
    titles, text = section
    # Фильтруем по произвольной длине, можно выбрать и другое значение
    if len(text) < 16:
        return False
    else:
        return True


original_num_sections = len(wikipedia_sections)
wikipedia_sections = [ws for ws in wikipedia_sections if keep_section(ws)]
print(f"Отфильтровано {original_num_sections-len(wikipedia_sections)} секций, осталось {len(wikipedia_sections)} секций.")
# Out:
# Отфильтровано 0 секций, осталось 5225 секций.

# %%
for ws in wikipedia_sections[:5]:
    print(ws[0])
    display(ws[1][:50] + "...")
    print()
# Out:
# ['NZ Performance Car']
# '{{Use dmy dates|date=December 2019}}\n{{Use New Zea...'
# ['NZ Performance Car', '==Change in focus==']
# "The magazine's focus has evolved from initially co..."
# ['NZ Performance Car', '==Change in focus==', '===Typical cars featured in NZ Performance Car===']
# '*[[Nissan Skyline GT-R]]\n*[[Nissan Silvia]]\n*[[Nis...'
# ['NZ Performance Car', '==Magazine contents==', '===Modified car features===']
# 'The extent that a car is required to be modified h...'
# ['NZ Performance Car', '==Magazine contents==', '===New car features===']
# 'Less common are new car road tests. Recent example...'

# %%
GPT_MODEL = "gpt-3.5-turbo"  # only matters insofar as it selects which tokenizer to use

# Функция подсчета токенов
def num_tokens(text: str, model: str = GPT_MODEL) -> int:
    """Возвращает число токенов в строке."""
    encoding = tiktoken.encoding_for_model(model)
    return len(encoding.encode(text))

# Функция разделения строк
def halved_by_delimiter(string: str, delimiter: str = "\n") -> List[str]:
    """Разделяет строку надвое с помощью разделителя (delimiter), пытаясь сбалансировать токены с каждой стороны."""

    # Делим строку на части по разделителю, по умолчанию \n - перенос строки
    chunks = string.split(delimiter)
    if len(chunks) == 1:
        return [string, ""]  # разделитель не найден
    elif len(chunks) == 2:
        return chunks  # нет необходимости искать промежуточную точку
    else:
        # Считаем токены
        total_tokens = num_tokens(string)
        halfway = total_tokens // 2
        # Предварительное разделение по середине числа токенов
        best_diff = halfway
        # В цикле ищем какой из разделителей, будет ближе всего к best_diff
        for i, chunk in enumerate(chunks):
            left = delimiter.join(chunks[: i + 1])
            left_tokens = num_tokens(left)
            diff = abs(halfway - left_tokens)
            if diff >= best_diff:
                break
            else:
                best_diff = diff
        left = delimiter.join(chunks[:i])
        right = delimiter.join(chunks[i:])
        # Возвращаем левую и правую часть оптимально разделенной строки
        return [left, right]


# Функция обрезает строку до максимально разрешенного числа токенов
def truncated_string(
    string: str, # строка
    model: str, # модель
    max_tokens: int, # максимальное число разрешенных токенов
    print_warning: bool = True, # флаг вывода предупреждения
) -> str:
    """Обрезка строки до максимально разрешенного числа токенов."""
    encoding = tiktoken.encoding_for_model(model)
    encoded_string = encoding.encode(string)
    # Обрезаем строку и декодируем обратно
    truncated_string = encoding.decode(encoded_string[:max_tokens])
    if print_warning and len(encoded_string) > max_tokens:
        print(f"Предупреждение: Строка обрезана с {len(encoded_string)} токенов до {max_tokens} токенов.")
    # Усеченная строка
    return truncated_string

# Функция делит секции статьи на части по максимальному числу токенов
def split_strings_from_subsection(
    subsection: Tuple[List[str], str], # секции
    max_tokens: int = 1000, # максимальное число токенов
    model: str = GPT_MODEL, # модель
    max_recursion: int = 5, # максимальное число рекурсий
) -> List[str]:
    """
    Разделяет секции на список из частей секций, в каждой части не более max_tokens.
    Каждая часть представляет собой кортеж родительских заголовков [H1, H2, ...] и текста (str).
    """
    titles, text = subsection
    string = "\n\n".join(titles + [text])
    num_tokens_in_string = num_tokens(string)
    # Если длина соответствует допустимой, то вернет строку
    if num_tokens_in_string <= max_tokens:
        return [string]
    # если в результате рекурсия не удалось разделить строку, то просто усечем ее по числу токенов
    elif max_recursion == 0:
        return [truncated_string(string, model=model, max_tokens=max_tokens)]
    # иначе разделим пополам и выполним рекурсию
    else:
        titles, text = subsection
        for delimiter in ["\n\n", "\n", ". "]: # Пробуем использовать разделители от большего к меньшему (разрыв, абзац, точка)
            left, right = halved_by_delimiter(text, delimiter=delimiter)
            if left == "" or right == "":
                # если какая-либо половина пуста, повторяем попытку с более простым разделителем
                continue
            else:
                # применим рекурсию на каждой половине
                results = []
                for half in [left, right]:
                    half_subsection = (titles, half)
                    half_strings = split_strings_from_subsection(
                        half_subsection,
                        max_tokens=max_tokens,
                        model=model,
                        max_recursion=max_recursion - 1, # уменьшаем максимальное число рекурсий
                    )
                    results.extend(half_strings)
                return results
    # иначе никакого разделения найдено не было, поэтому просто обрезаем строку (должно быть очень редко)
    return [truncated_string(string, model=model, max_tokens=max_tokens)]

# %%
# Делим секции на части
MAX_TOKENS = 1600
wikipedia_strings = []
for section in wikipedia_sections:
    wikipedia_strings.extend(split_strings_from_subsection(section, max_tokens=MAX_TOKENS))

print(f"{len(wikipedia_sections)} секций Википедии поделены на {len(wikipedia_strings)} строк.")
# Out:
# Предупреждение: Строка обрезана с 3852 токенов до 1600 токенов.
# Предупреждение: Строка обрезана с 2865 токенов до 1600 токенов.
# Предупреждение: Строка обрезана с 2865 токенов до 1600 токенов.
# Предупреждение: Строка обрезана с 2867 токенов до 1600 токенов.
# Предупреждение: Строка обрезана с 2868 токенов до 1600 токенов.
# Предупреждение: Строка обрезана с 2877 токенов до 1600 токенов.
# Предупреждение: Строка обрезана с 2857 токенов до 1600 токенов.
# Предупреждение: Строка обрезана с 2872 токенов до 1600 токенов.
# Предупреждение: Строка обрезана с 2863 токенов до 1600 токенов.
# 5225 секций Википедии поделены на 5384 строк.

# %%
# Напечатаем пример строки
print(wikipedia_strings[1])
# Out:
# NZ Performance Car
#
# ==Change in focus==
#
# The magazine's focus has evolved from initially covering all high performance cars, including Australian [[V8 engine|V8]]s, to [[Japanese Domestic Market|Japanese import cars]], and more recently import car culture and associated activities ([[BMX]], [[Freestyle Motocross|FMX]], interviews with local and international musicians, etc.).
#
# Early issues featured cars such as [[Holden Torana]]s alongside [[Mitsubishi]] [[Mitsubishi Galant VR-4|Galant VR4s.]]

# %%
from openai import OpenAI
import os
import getpass

EMBEDDING_MODEL = "text-embedding-ada-002"  # Модель токенизации от OpenAI

os.environ["OPENAI_API_KEY"] = getpass.getpass("Введите OpenAI API Key:")
client = OpenAI(api_key = os.environ.get("OPENAI_API_KEY"))

# Функция отправки chatGPT строки для ее токенизации (вычисления эмбедингов)
def get_embedding(text, model="text-embedding-ada-002"):

   return client.embeddings.create(input = [text], model=model).data[0].embedding

# %%
df = pd.DataFrame({"text": wikipedia_strings})

df['embedding'] = df.text.apply(lambda x: get_embedding(x, model='text-embedding-ada-002'))

SAVE_PATH = "./automobile.csv"
# Сохранение результата
df.to_csv(SAVE_PATH, index=False)

# %%
import pickle

file = open('./automobile.pickle', 'wb')
pickle.dump(df, file)
file.close()

# %%
df.head()
# Out:
#                                                 text  \
# 0  NZ Performance Car\n\n{{Use dmy dates|date=Dec...
# 1  NZ Performance Car\n\n==Change in focus==\n\nT...
# 2  NZ Performance Car\n\n==Change in focus==\n\n=...
# 3  NZ Performance Car\n\n==Magazine contents==\n\...
# 4  NZ Performance Car\n\n==Magazine contents==\n\...
#
#                                            embedding
# 0  [-0.02061622031033039, 0.003011121414601803, 0...
# 1  [-0.017560184001922607, 0.00253809941932559, 0...
# 2  [-0.008404873311519623, 0.009192416444420815, ...
# 3  [0.0006532236002385616, 0.011562341824173927, ...
# 4  [-0.01238475926220417, 0.017139919102191925, 0...

# %%
from scipy import spatial  # вычисляет сходство векторов


# Функция поиска
def strings_ranked_by_relatedness(
    query: str, # пользовательский запрос
    df: pd.DataFrame, # DataFrame со столбцами text и embedding (база знаний)
    relatedness_fn=lambda x, y: 1 - spatial.distance.cosine(x, y), # функция схожести, косинусное расстояние
    top_n: int = 100 # выбор лучших n-результатов
) -> Tuple[List[str], List[float]]: # Функция возвращает кортеж двух списков, первый содержит строки, второй - числа с плавающей запятой
    """Возвращает строки и схожести, отсортированные от большего к меньшему"""

    # Отправляем в OpenAI API пользовательский запрос для токенизации
    query_embedding_response = openai.embeddings.create(
        model=EMBEDDING_MODEL,
        input=query,
    )

    # Получен токенизированный пользовательский запрос
    query_embedding = query_embedding_response.data[0].embedding

    # Сравниваем пользовательский запрос с каждой токенизированной строкой DataFrame
    strings_and_relatednesses = [
        (row["text"], relatedness_fn(query_embedding, row["embedding"]))
        for i, row in df.iterrows()
    ]

    # Сортируем по убыванию схожести полученный список
    strings_and_relatednesses.sort(key=lambda x: x[1], reverse=True)

    # Преобразовываем наш список в кортеж из списков
    strings, relatednesses = zip(*strings_and_relatednesses)

    # Возвращаем n лучших результатов
    return strings[:top_n], relatednesses[:top_n]

# %%
strings, relatednesses = strings_ranked_by_relatedness("fast car speed", df, top_n=5)
for string, relatedness in zip(strings, relatednesses):
    print(f"{relatedness=:.3f}")
    display(string)
# Out:
# relatedness=0.800
# 'NZ Performance Car\n\n==Magazine contents==\n\n===Modified car features===\n\nThe extent that a car is required to be modified has steadily increased since the first issues. While 300&nbsp;hp was considered to be a huge amount of power when the magazine started, 300&nbsp;kW may not even secure a spot as a feature car, unless the rest of the car is outstanding or unusual.\n\nThis is not to say that NZ Performance Car solely focuses on power, but power figures are part of a more holistic approach considered when modifying a car.'
# relatedness=0.791
# 'NZ Performance Car\n\n==Magazine contents==\n\n===Event coverage===\n\n[[Drag racing]], [[Drifting (motorsport)|drifting]], [[rallying]], [[Super Lap]], Japanese [[Super GT]], [[hillclimbing]], [[touring cars]], auto salon, [[auto show]]s and club events are covered, as long as the racing includes Japanese cars.'
# relatedness=0.789
# "NZ Performance Car\n\n==Change in focus==\n\nThe magazine's focus has evolved from initially covering all high performance cars, including Australian [[V8 engine|V8]]s, to [[Japanese Domestic Market|Japanese import cars]], and more recently import car culture and associated activities ([[BMX]], [[Freestyle Motocross|FMX]], interviews with local and international musicians, etc.).\n\nEarly issues featured cars such as [[Holden Torana]]s alongside [[Mitsubishi]] [[Mitsubishi Galant VR-4|Galant VR4s.]]"
# relatedness=0.788
# 'NZ Performance Car\n\n==Change in focus==\n\n===Typical cars featured in NZ Performance Car===\n\n*[[Nissan Skyline GT-R]]\n*[[Nissan Silvia]]\n*[[Nissan Pulsar GTI-R]]\n*[[Nissan 300ZX]]\n*[[Nissan 350Z]]\n*[[Nissan Laurel]]\n*[[Subaru WRX]]\n*[[Subaru Legacy]]\n*[[Mitsubishi Lancer Evolution]]\n*[[Honda Integra]]\n*[[Honda Civic]]\n*[[Honda S2000]]\n*[[Toyota Celica]]\n*[[Toyota Supra]]\n*[[Toyota AE86|Toyota Levin AE86]]\n*[[Toyota Altezza]]\n*[[Mazda RX-7]]\n*[[Mazda 323]]\n*[[Mitsubishi Galant VR4]]\n*[[Toyota Hilux]]\n*[[Mazda GTX]]\n*[[Toyota Chaser]]'
# relatedness=0.783
# 'NZ Performance Car\n\n==Magazine contents==\n\n===Driver and celebrity interviews===\n\nLocal and international drivers have been interviewed such as [[Ken Block (rally driver)|Ken Block]], [[Rhys Millen]], [[Mike Whiddett]], [[Sébastien Loeb]], [[Linkin Park]]/[[Fort Minor]] and Nathalie Kelly (from [[Fast n Furious Tokyo Drift]]),'
